# %%
import pandas as pd

# %%
# Import
dataset = pd.read_csv("movie_metadata.csv")

# %%
#Preparar Dados para Questoes
def DadosQ1(dataset):
    return dataset[["gross","movie_title"][:]]
def DadosQ2(dataset):
    return dataset[["gross","language","movie_title"][:]]
def DadosQ3(dataset):

# %%
# Funcoes
def Q1(dataset):
    return dataset.gross.idxmax()

def Q2(dataset):
    df = dataset[["gross","language","movie_title"][:]]
    df.groupby("language").max()
    
def Q3(dataset):

# %%
# Out:
#                   gross                                  movie_title
# language
# Aboriginal   72515360.0                             The Interpreter
# Arabic        1060591.0                  Valley of the Wolves: Iraq
# Aramaic        499263.0                   The Passion of the Christ
# Bosnian        301305.0              In the Land of Blood and Honey
# Cantonese    32333860.0                                     Z Storm
# Chinese         50000.0                              Out of Inferno
# Czech          617228.0                I Served the King of England
# Danish        1647780.0                                    The Hunt
# Dari         15797907.0                             The Kite Runner
# Dutch         4398392.0                           Winter in Wartime
# Dzongkha       505295.0                     Travelers and Magicians
# English     760505847.0                                    Æon Flux
# Filipino     10166502.0                              The Great Raid
# French       77413017.0                                  Wild Grass
# German       11433134.0                            The White Ribbon
# Greek          110197.0                                    Dogtooth
# Hebrew        2408553.0                           Waltz with Bashir
# Hindi        13876974.0                     Yeh Jawaani Hai Deewani
# Hungarian      195888.0                                    Fateless
# Icelandic       11835.0                         Trapped
# Indonesian    4105123.0                        The Raid: Redemption
# Italian      15091542.0                            The Great Beauty
# Japanese     15081783.0         Yu-Gi-Oh! Duel Monsters
# Kannada             NaN                                       Barfi
# Kazakh          77231.0                          Nomad: The Warrior
# Korean        2201412.0                                  Tidal Wave
# Mandarin    128067808.0  Three Kingdoms: Resurrection of the Dragon
# Maya         50859889.0                                  Apocalypto
# Mongolian     5701643.0            Mongol: The Rise of Genghis Khan
# None          2601847.0                                     Samsara
# Norwegian     1196752.0                                 Trollhunter
# Panjabi             NaN                                  Sardaar Ji
# Persian       7098492.0                                  The Circle
# Polish        3826455.0                      The Border
# Portuguese    7563397.0                                       Trash
# Romanian      1185783.0                           The World Is Mine
# Russian       1487477.0                                         Viy
# Slovenian           NaN                        Julija in alfa Romeo
# Spanish      45356386.0                                       [Rec]
# Swahili             NaN                        Stories of Our Lives
# Swedish        188870.0                                  Easy Money
# Tamil               NaN                                       Vaalu
# Telugu        6498000.0                    Baahubali: The Beginning
# Thai         11905519.0                               The Protector
# Urdu                NaN                           Karachi se Lahore
# Vietnamese     638951.0                       Journey from the Fall
# Zulu          2912363.0                                      Tsotsi

# %%
dataset.shape
# Out:
# (5043, 28)
